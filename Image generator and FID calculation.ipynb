# %% [markdown]
# ### **Старт, базовые штуки и загрузка библиотек**

# %%
import zipfile

with zipfile.ZipFile('/content/edm-main.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/edm-main')

# %%
import sys
sys.path.append(r'/content/edm-main/edm-main/')

# %%
import tqdm
import pickle
import numpy as np
import torch
import PIL.Image
import dnnlib
import os
from torchvision import datasets
import torchvision.transforms as transforms

# %%
pip install pytorch_fid
# Out:
# Requirement already satisfied: pytorch_fid in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pytorch_fid) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from pytorch_fid) (10.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pytorch_fid) (1.13.1)
# Requirement already satisfied: torch>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from pytorch_fid) (2.5.0+cu121)
# Requirement already satisfied: torchvision>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from pytorch_fid) (0.20.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch_fid) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch_fid) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch_fid) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch_fid) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch_fid) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch_fid) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.0.1->pytorch_fid) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.1->pytorch_fid) (3.0.2)

# %%
import shutil
import subprocess
import tempfile
import random

from pytorch_fid.fid_score import calculate_fid_given_paths

# %% [markdown]
# ### **Скачивание датасета Cifar10**

# %%
def download_cifar10_images(dest_dir='cifar10_images'):
    os.makedirs(dest_dir, exist_ok=True)
    transform = transforms.ToPILImage()
    dataset = datasets.CIFAR10(root='./data', train=False, download=True)

    for idx, (image, _) in enumerate(dataset):
        image.save(os.path.join(dest_dir, f'image_{idx:04d}.png'))

    print(f'CIFAR-10 images saved to {dest_dir}')

download_cifar10_images()
# Out:
# Files already downloaded and verified
# CIFAR-10 images saved to cifar10_images

# %%
dataset_dir = 'cifar10_images'

# %% [markdown]
# ### **Генератор изображений по батчу**

# %%
torch.manual_seed(52)

# %%
def get_next_index(dest_dir):
    """Finds the next available image index in the destination directory."""
    existing_files = [f for f in os.listdir(dest_dir) if f.startswith('image_') and f.endswith('.png')]
    if existing_files:
        indices = [int(f.split('_')[1].split('.')[0]) for f in existing_files]
        return max(indices) + 1
    else:
        return 0

# %%
def sample_images_batch(
    net, dest_path, hoen = True,
    seed=42, batch_size = 100, device=torch.device('cuda'),
    num_steps=18, sigma_min=0.002, sigma_max=80, rho=7,
    S_churn=0, S_min=0, S_max=float('inf'), S_noise=1,
    start_index = 0
):
    # Adjust noise levels based on what's supported by the network.
    sigma_min = max(sigma_min, net.sigma_min)
    sigma_max = min(sigma_max, net.sigma_max)

    # Time step discretization.
    step_indices = torch.arange(num_steps, dtype=torch.float64, device=device)
    # Рассчитываем временные шаги
    t_steps = (sigma_max ** (1 / rho) + step_indices / (num_steps - 1) * (sigma_min ** (1 / rho) - sigma_max ** (1 / rho))) ** rho
    # Нулевой шаг в конец (t_{N})
    t_steps = torch.cat([net.round_sigma(t_steps), torch.zeros_like(t_steps[:1])]) # t_N = 0

    latents = torch.randn([batch_size, net.img_channels, net.img_resolution, net.img_resolution], device=device)

    # Main sampling loop.
    x_next = latents.to(torch.float64) * t_steps[0]  # Шаг 1
    for i, (t_cur, t_next) in list(enumerate(zip(t_steps[:-1], t_steps[1:]))): # 0, ..., N-1
        x_cur = x_next

        # Increase noise temporarily. // увеличение шума
        gamma = min(S_churn / num_steps, np.sqrt(2) - 1) if S_min <= t_cur <= S_max else 0
        t_hat = net.round_sigma(t_cur + gamma * t_cur)
        x_hat = x_cur + (t_hat ** 2 - t_cur ** 2).sqrt() * S_noise * torch.randn_like(x_cur)

        # Euler step. // убрал классы так как у нас анконд
        denoised = net(x_hat, t_hat).to(torch.float64)
        d_cur = (x_hat - denoised) / t_hat
        x_next = x_hat + (t_next - t_hat) * d_cur

        # Apply 2nd order correction. // Hoen //  убрал классы так как у нас анконд
        if hoen == True:
            if i < num_steps - 1:
                denoised = net(x_next, t_next).to(torch.float64)
                d_prime = (x_next - denoised) / t_next
                x_next = x_hat + (t_next - t_hat) * (0.5 * d_cur + 0.5 * d_prime)

    images = (x_next * 127.5 + 128).clip(0, 255).to(torch.uint8).cpu()
    for idx, image in enumerate(images):
        img = image.permute(1, 2, 0).numpy()
        img = PIL.Image.fromarray(img, 'RGB')
        img.save(os.path.join(dest_dir, f'image_{start_index+idx}.png'))

# %% [markdown]
# ### **Генератор изображений и разбиение изображений на сабсеты**

# %%
def generate_required_images(
    net, required_images, num_steps, dest_dir, hoen,
    batch_size=100, seed=42, device=torch.device('cuda')
):
    os.makedirs(dest_dir, exist_ok=True)

    n_runs = required_images//batch_size

    for i in tqdm.tqdm(range (n_runs)):
        generated_images = get_next_index(dest_dir)
        sample_images_batch(
            net, dest_dir, hoen,
            batch_size=batch_size, device=device, num_steps=num_steps,
            start_index=generated_images
        )

# %% [markdown]
# ### **Расчет фида**

# %%
def create_subsets(input_dir, output_dir, counts):
    for count in counts:
        subset_dir = os.path.join(output_dir, f"subset_{count}")
        os.makedirs(subset_dir, exist_ok=True)

        all_files = sorted(os.listdir(input_dir))[:count]
        for file_name in all_files:
            full_file_name = os.path.join(input_dir, file_name)
            if os.path.isfile(full_file_name):
                shutil.copy(full_file_name, subset_dir)

def calculate_fid_for_subsets(dataset_dir, output_dir, counts, batch_size=100,
                              device=torch.device('cuda:0' if torch.cuda.is_available() else 'cpu'),
                              dims=2048, num_workers=12, dataset_sabsets_usage = True):
    fid_values = []
    for count in counts:
        subset_dir_output = os.path.join(output_dir, f"subset_{count}")
        if dataset_sabsets_usage==True:
            subset_dir_dataset = os.path.join(dataset_dir, f"subset_{count}")
        else:
            subset_dir_dataset = dataset_dir

        fid = calculate_fid_given_paths(
            [subset_dir_output, subset_dir_dataset],
            batch_size=batch_size,
            device=device,
            dims=dims,
            num_workers=num_workers)
        fid_values.append(fid)
    return fid_values

# %%
create_subsets(dataset_dir, dataset_dir, [50000])

# %% [markdown]
# ### **Сборка и запуск генератора и расчета фида**

# %%
network_pkl = 'https://nvlabs-fi-cdn.nvidia.com/edm/pretrained/edm-cifar10-32x32-uncond-vp.pkl'

with dnnlib.util.open_url(network_pkl) as f:
    net = pickle.load(f)['ema'].to(torch.device('cuda'))

# %%
num_steps_list = [10, 20, 30, 50]

fid_values_Eiler_full_dataset_list = []
fid_values_Eiler_sabset_dataset_list = []

fid_values_Hoen_full_dataset_list = []
fid_values_Hoen_sabset_dataset_list = []

for num_steps in num_steps_list:
    print(f'clculating for {num_steps} steps')

    dest_dir = f'gen_images_Eiler_{num_steps}'
    generate_required_images(net, 50000, num_steps, dest_dir, False, batch_size = 2000)
    create_subsets(dest_dir, dest_dir, [50000])

    fid_values_Eiler_full_dataset = calculate_fid_for_subsets(dataset_dir, dest_dir, [50000], dataset_sabsets_usage = False)
    fid_values_Eiler_full_dataset_list.append(fid_values_Eiler_full_dataset)
    print(f'fid for Eiler full dataset: {fid_values_Eiler_full_dataset}')

    fid_values_Eiler_sabset_dataset = calculate_fid_for_subsets(dataset_dir, dest_dir, [50000], dataset_sabsets_usage = True)
    fid_values_Eiler_sabset_dataset_list.append(fid_values_Eiler_sabset_dataset)
    print(f'fid for Eiler sabset dataset: {fid_values_Eiler_sabset_dataset}')

    with zipfile.ZipFile(f'{dest_dir}.zip', 'w') as zipf:
        for root, _, files in os.walk(dest_dir):
            for file in files:
                zipf.write(os.path.join(root, file), file)

    dest_dir = f'gen_images_Hoen_{num_steps}'
    generate_required_images(net, 50000, num_steps, dest_dir, True, batch_size = 2000)
    create_subsets(dest_dir, dest_dir, [50000])

    fid_values_Hoen_full_dataset = calculate_fid_for_subsets(dataset_dir, dest_dir, [50000], dataset_sabsets_usage = False)
    fid_values_Hoen_full_dataset_list.append(fid_values_Hoen_full_dataset)
    print(f'fid for Hoen full dataset: {fid_values_Hoen_full_dataset}')


    fid_values_Hoen_sabset_dataset = calculate_fid_for_subsets(dataset_dir, dest_dir, [50000], dataset_sabsets_usage = True)
    fid_values_Hoen_sabset_dataset_list.append(fid_values_Hoen_sabset_dataset)
    print(f'fid for Hoen sabset dataset: {fid_values_Hoen_sabset_dataset}')

    # Create ZIP for Hoen
    with zipfile.ZipFile(f'{dest_dir}.zip', 'w') as zipf:
        for root, _, files in os.walk(dest_dir):
            for file in files:
                zipf.write(os.path.join(root, file), file)
# Out:
# clculating for 10 steps
# 100%|██████████| 25/25 [06:31<00:00, 15.67s/it]
# 100%|██████████| 500/500 [00:24<00:00, 20.21it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.07it/s]
# fid for Eiler full dataset: [21.27304551901983]
# 100%|██████████| 500/500 [00:24<00:00, 20.25it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.76it/s]
# fid for Eiler sabset dataset: [21.27304551901983]
# Выходные данные были обрезаны до нескольких последних строк (5000).
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_48285.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_3739.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_10377.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_49170.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_33108.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_22283.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_12607.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_1454.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_49725.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_23743.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_28497.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_21760.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_16498.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_24908.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_9343.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_33320.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_20292.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_15476.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_32844.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_15349.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_35907.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_10266.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_44913.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_46410.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_2800.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_17893.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_13569.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_21425.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_43800.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_20034.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_18325.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_6183.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_47896.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_18587.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_15662.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_16726.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_2440.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_3421.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_3513.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_37162.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_4651.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_12303.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_41832.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_951.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_3102.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_36311.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_29345.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_5532.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_16376.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_42437.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_29180.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_18257.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_40527.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_30300.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_4033.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_28173.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_36299.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_43499.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_13353.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_14703.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_39196.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_10902.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_34320.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_8373.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_9374.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_44312.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_5114.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_17689.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_1546.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_41667.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_28343.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_49747.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_7249.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_40362.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_20413.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_18391.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_16614.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_36456.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_34305.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_11688.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_5666.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_7964.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_13123.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_27553.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_4731.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_13959.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_647.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_5824.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_36226.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_18906.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_30966.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_49698.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_20860.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_49828.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_48584.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_11139.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_49197.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_6237.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_48274.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_27792.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_33951.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_20316.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_2962.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_4664.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_5517.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_38214.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_36524.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_13060.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_17143.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_15651.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_25151.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_30319.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_36662.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_42923.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_48032.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_34303.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_17530.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_12951.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_1890.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_31701.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_29148.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_18648.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_27951.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_37759.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_43754.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_10304.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_30224.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_9058.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_7809.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_28156.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_5894.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_34101.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_33163.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_29726.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_13618.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_45987.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_8907.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_19277.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_30335.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_19463.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_49030.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_20822.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_28169.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_14382.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_45024.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_26271.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_41412.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_25380.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_34425.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_8763.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_10057.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_48383.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_5852.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_30111.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_25081.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_8672.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_20722.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_34732.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_17752.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_44523.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_28056.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_44857.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_9816.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_24432.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_16432.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_30177.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_48098.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_29104.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_22698.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_6277.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_6788.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_45584.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_41317.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_43196.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_17794.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_38686.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_293.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_49672.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_3618.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_28894.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_10707.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_17055.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_34920.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_38249.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_14986.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_9400.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_45051.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_10388.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_27099.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_12721.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_40617.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_36411.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_16472.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_33426.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_48152.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_27235.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_6872.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_27713.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_11673.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_5394.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_34071.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_3467.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_40889.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_40695.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_36143.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_27502.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_1244.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_16998.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_21472.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_17925.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_3802.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_37980.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_36984.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_19288.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_9000.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_30394.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_41363.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_38441.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_38006.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_28193.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_10390.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_26607.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_44132.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_33272.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_24087.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_29287.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_48232.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_49689.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_40974.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_35799.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_16354.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_27013.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_36117.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_23636.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_47937.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_21312.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_41729.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_17908.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_39266.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_42998.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_49706.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_31359.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_48441.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_752.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_48694.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_11114.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_5714.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_9402.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_31146.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_31112.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_6525.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_13439.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_21800.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_29273.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_1551.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_870.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_2534.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_44363.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_12963.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_3630.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_33216.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_22751.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_966.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_2873.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_37376.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_36391.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_34276.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_36087.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_15084.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_32671.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_43607.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_10213.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_34307.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_671.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_23194.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_18653.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_6077.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_35781.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_4928.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_4286.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_28713.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_35862.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_4794.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_43034.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_20959.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_20952.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_4843.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_34402.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_45463.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_31897.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_2702.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_26833.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_5707.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_32166.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_34225.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_31562.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_14445.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_17633.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_32726.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_22353.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_9997.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_24757.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_23878.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_15316.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_21921.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_46778.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_9489.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_35899.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_12280.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_5094.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_46419.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_46710.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_16043.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_18316.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_23544.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_35214.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_22249.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_3303.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_18727.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_35139.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_4421.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_11101.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_18350.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_22888.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_9336.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_33764.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_35356.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_22527.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# ...
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_24166.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_43883.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_41276.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_16436.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_9656.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_42920.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_19655.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_37493.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_28623.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_5192.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_41704.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_34057.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_42616.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_16163.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_1324.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_24125.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_42303.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_24863.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_7428.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_11192.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_25862.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_15601.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_2403.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_2953.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_4805.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_28805.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_42591.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_1671.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_10225.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_44173.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_13355.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_41120.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_44863.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_5422.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_23555.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_38417.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_9269.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_15203.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_29627.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_47109.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_6177.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_16822.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_27177.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_28310.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_551.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_41949.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_30260.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_30687.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_5560.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_818.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_37588.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_40624.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_14490.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_43795.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_15717.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_29908.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_13094.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_48225.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_14503.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_11995.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_31207.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_1374.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_40720.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_9294.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_19513.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_4715.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_19157.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_25843.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_26033.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_3327.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_379.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_33360.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_4254.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_18631.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_5944.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_21923.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_29206.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_41844.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_24772.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_11518.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_3830.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_39353.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_2213.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_13164.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_24674.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_33810.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_153.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_43275.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_44124.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_47758.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_47891.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_27907.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# /usr/lib/python3.10/zipfile.py:1528: UserWarning: Duplicate name: 'image_48112.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# 100%|██████████| 25/25 [12:02<00:00, 28.92s/it]
# 100%|██████████| 500/500 [00:24<00:00, 20.26it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.87it/s]
# fid for Hoen full dataset: [4.874457315149471]
# 100%|██████████| 500/500 [00:24<00:00, 20.23it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.06it/s]
# fid for Hoen sabset dataset: [4.874457315149471]
# clculating for 20 steps
# 100%|██████████| 25/25 [12:40<00:00, 30.41s/it]
# 100%|██████████| 500/500 [00:24<00:00, 20.24it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.10it/s]
# fid for Eiler full dataset: [8.829072797287324]
# 100%|██████████| 500/500 [00:24<00:00, 20.27it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.96it/s]
# fid for Eiler sabset dataset: [8.829072797287324]
# 100%|██████████| 25/25 [24:20<00:00, 58.44s/it]
# 100%|██████████| 500/500 [00:24<00:00, 20.28it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.03it/s]
# fid for Hoen full dataset: [4.155084641681583]
# 100%|██████████| 500/500 [00:24<00:00, 20.24it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.92it/s]
# fid for Hoen sabset dataset: [4.155084641681583]
# clculating for 30 steps
# 100%|██████████| 25/25 [18:49<00:00, 45.18s/it]
# 100%|██████████| 500/500 [00:24<00:00, 20.24it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.99it/s]
# fid for Eiler full dataset: [6.52219291192273]
# 100%|██████████| 500/500 [00:24<00:00, 20.27it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.91it/s]
# fid for Eiler sabset dataset: [6.52219291192273]
# 100%|██████████| 25/25 [36:39<00:00, 87.97s/it]
# 100%|██████████| 500/500 [00:24<00:00, 20.24it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.09it/s]
# fid for Hoen full dataset: [4.174577281922836]
# 100%|██████████| 500/500 [00:24<00:00, 20.16it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.97it/s]
# fid for Hoen sabset dataset: [4.174577281922836]
# clculating for 50 steps
# 100%|██████████| 25/25 [31:07<00:00, 74.72s/it]
# 100%|██████████| 500/500 [00:24<00:00, 20.21it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.08it/s]
# fid for Eiler full dataset: [5.240002383179899]
# 100%|██████████| 500/500 [00:24<00:00, 20.21it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.77it/s]
# fid for Eiler sabset dataset: [5.240002383179899]
# 100%|██████████| 25/25 [1:01:16<00:00, 147.06s/it]
# 100%|██████████| 500/500 [00:24<00:00, 20.21it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.83it/s]
# fid for Hoen full dataset: [4.204482852003707]
# 100%|██████████| 500/500 [00:24<00:00, 20.21it/s]
# 100%|██████████| 100/100 [00:05<00:00, 18.70it/s]
# fid for Hoen sabset dataset: [4.204482852003707]

# %% [markdown]
# ### **Отображение результатов**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(num_steps_list, fid_values_Hoen_full_dataset_list, marker='o', linestyle='--', color='b', label='HEUN METHOD')
plt.plot(num_steps_list, fid_values_Eiler_full_dataset_list, marker='o', linestyle='--', color='r', label='EILER METHOD')

plt.xlabel('Num_steps')
plt.ylabel('FID Score')
plt.title('FID Score vs. Num_steps')
plt.grid(True)
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(num_steps_list, fid_values_Hoen_sabset_dataset_list, marker='o', linestyle='--', color='b', label='HEUN METHOD')
plt.plot(num_steps_list, fid_values_Eiler_sabset_dataset_list, marker='o', linestyle='--', color='r', label='EILER METHOD')

plt.xlabel('Num_steps')
plt.ylabel('FID Score')
plt.title('FID Score vs. Num_steps')
plt.grid(True)
plt.legend()

plt.show()

# %%
fid_values_Hoen_full_dataset_list
# Out:
# [[4.874457315149471],
#  [4.155084641681583],
#  [4.174577281922836],
#  [4.204482852003707]]

# %%
fid_values_Eiler_sabset_dataset_list
# Out:
# [[21.27304551901983],
#  [8.829072797287324],
#  [6.52219291192273],
#  [5.240002383179899]]
